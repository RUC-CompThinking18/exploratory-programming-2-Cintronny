# %%
def count(list):
    x = []
    for element in list:
        x = int(len([x for x in list if x > 0]))
        #telling it to return the argument with how many elements are greater than 0 in the list
    return x
#telling it to end the loop with the outcome of the equation

count([3, 5, 2, -4, -9])
# Out:
# 3

# %%
apple = [3, 23, 5, -2, -3, -12]
count(apple)
# Out:
# 3

# %%
peach = [12, 4, -12, 90, -2]

count(peach + apple)
